# %%
def key_expansion(byte_key):
    word_w = [0] * 44

    for i in range(4):
        word_w[i] = (
            int(byte_key[i][0], 16) << 24 |
            int(byte_key[i][1], 16) << 16 |
            int(byte_key[i][2], 16) << 8 |
            int(byte_key[i][3], 16)
        )

    for i in range(4, 44):
        temp = word_w[i - 1]
        if i % 4 == 0:
            temp = sub_word(rot_word(temp)) ^ rcon[i // 4]

        word_w[i] = word_w[i - 4] ^ temp

    return word_w

def sub_word(word):
    return (
        (s_box[(word >> 24) & 0xFF] << 24) |
        (s_box[(word >> 16) & 0xFF] << 16) |
        (s_box[(word >> 8) & 0xFF] << 8) |
        (s_box[word & 0xFF])
    )

def rot_word(word):
    return ((word << 8) | (word >> 24)) & 0xFFFFFFFF

# Define the correct round constants based on RC
rcon = [0x00]
for j in range(1, 11):
    rcon.append(((rcon[j - 1] << 1) ^ (0x11B if (rcon[j - 1] & 0x80) else 0)) & 0xFF)


s_box = [
        
        ]



key = [
    ["54", "68", "61", "74"],
    ["73", "20", "6d", "79"],
    ["20", "4b", "75", "6e"],
    ["67", "20", "46", "75"],
]

# Perform key expansion
expanded_key = key_expansion(key)   
expanded_key_hex_2d = [
    [hex(word)[2:].zfill(8) for word in expanded_key[i:i+4]]
    for i in range(0, len(expanded_key), 4)
]

for i in range(10):
    globals()[f'key{i}'] = [[val[j:j+2].upper() for j in range(0, len(val), 2)] for val in expanded_key_hex_2d[i]]


for i in range(10):
    key_name = f'key{i}'
    print(f"Contents of {key_name}:")
    for row in globals()[key_name]:
        print(" ".join(row))
    print("\n")
# Out:
# Contents of key0:
# 54 68 61 74
# 73 20 6D 79
# 20 4B 75 6E
# 67 20 46 75
#
#
# Contents of key1:
# E3 32 FC F1
# 90 12 91 88
# B0 59 E4 E6
# D7 79 A2 93
#
#
# Contents of key2:
# 55 08 20 FF
# C5 1A B1 77
# 75 43 55 91
# A2 3A F7 02
#
#
# Contents of key3:
# D5 60 57 C5
# 10 7A E6 B2
# 65 39 B3 23
# C7 03 44 21
#
#
# Contents of key4:
# AE 7B AA 03
# BE 01 4C B1
# DB 38 FF 92
# 1C 3B BB B3
#
#
# Contents of key5:
# 4C 91 C7 9F
# F2 90 8B 2E
# 29 A8 74 BC
# 35 93 CF 0F
#
#
# Contents of key6:
# 90 1B B1 09
# 62 8B 3A 27
# 4B 23 4E 9B
# 7E B0 81 94
#
#
# Contents of key7:
# 77 17 93 FA
# 15 9C A9 DD
# 5E BF E7 46
# 20 0F 66 D2
#
#
# Contents of key8:
# 01 24 26 4D
# 14 B8 8F 90
# 4A 07 68 D6
# 6A 08 0E 04
#
#
# Contents of key9:
# 31 8F D4 4F
# 25 37 5B DF
# 6F 30 33 09
# 05 38 3D 0D

# %%
class AES:
    def __init__(self):
        self.block=[
            ["47",  "40"  , "A3"  ,"4C"],
            ["37",  "D4"  , "70"  ,"9F"],
            ["94",  "E4",  "3A"  ,"42"],
            ["ED",  "A5",  "A6",  "BC"],
        ]
        self.key=[
            ["AC",  "19"  , "28"  ,"57"],
            ["77",  "FA"  , "D1"  ,"5C"],
            ["66",  "DC",  "29"  ,"00"],
            ["F3",  "21",  "41",  "6A"],
        ]
        self.r_con = (
                        0x00, 0x01, 0x02, 0x04, 0x08, 0x10, 0x20, 0x40,
                        0x80, 0x1B, 0x36, 0x6C, 0xD8, 0xAB, 0x4D, 0x9A,
                        0x2F, 0x5E, 0xBC, 0x63, 0xC6, 0x97, 0x35, 0x6A,
                        0xD4, 0xB3, 0x7D, 0xFA, 0xEF, 0xC5, 0x91, 0x39,
                    )
        self.encrypted_matrix=[]
        self.s_box = [
        [0x63, 0x7C, 0x77, 0x7B, 0xF2, 0x6B, 0x6F, 0xC5, 0x30, 0x01, 0x67, 0x2B, 0xFE, 0xD7, 0xAB, 0x76],
        [0xCA, 0x82, 0xC9, 0x7D, 0xFA, 0x59, 0x47, 0xF0, 0xAD, 0xD4, 0xA2, 0xAF, 0x9C, 0xA4, 0x72, 0xC0],
        [0xB7, 0xFD, 0x93, 0x26, 0x36, 0x3F, 0xF7, 0xCC, 0x34, 0xA5, 0xE5, 0xF1, 0x71, 0xD8, 0x31, 0x15],
        [0x04, 0xC7, 0x23, 0xC3, 0x18, 0x96, 0x05, 0x9A, 0x07, 0x12, 0x80, 0xE2, 0xEB, 0x27, 0xB2, 0x75],
        [0x09, 0x83, 0x2C, 0x1A, 0x1B, 0x6E, 0x5A, 0xA0, 0x52, 0x3B, 0xD6, 0xB3, 0x29, 0xE3, 0x2F, 0x84],
        [0x53, 0xD1, 0x00, 0xED, 0x20, 0xFC, 0xB1, 0x5B, 0x6A, 0xCB, 0xBE, 0x39, 0x4A, 0x4C, 0x58, 0xCF],
        [0xD0, 0xEF, 0xAA, 0xFB, 0x43, 0x4D, 0x33, 0x85, 0x45, 0xF9, 0x02, 0x7F, 0x50, 0x3C, 0x9F, 0xA8],
        [0x51, 0xA3, 0x40, 0x8F, 0x92, 0x9D, 0x38, 0xF5, 0xBC, 0xB6, 0xDA, 0x21, 0x10, 0xFF, 0xF3, 0xD2],
        [0xCD, 0x0C, 0x13, 0xEC, 0x5F, 0x97, 0x44, 0x17, 0xC4, 0xA7, 0x7E, 0x3D, 0x64, 0x5D, 0x19, 0x73],
        [0x60, 0x81, 0x4F, 0xDC, 0x22, 0x2A, 0x90, 0x88, 0x46, 0xEE, 0xB8, 0x14, 0xDE, 0x5E, 0x0B, 0xDB],
        [0xE0, 0x32, 0x3A, 0x0A, 0x49, 0x06, 0x24, 0x5C, 0xC2, 0xD3, 0xAC, 0x62, 0x91, 0x95, 0xE4, 0x79],
        [0xE7, 0xC8, 0x37, 0x6D, 0x8D, 0xD5, 0x4E, 0xA9, 0x6C, 0x56, 0xF4, 0xEA, 0x65, 0x7A, 0xAE, 0x08],
        [0xBA, 0x78, 0x25, 0x2E, 0x1C, 0xA6, 0xB4, 0xC6, 0xE8, 0xDD, 0x74, 0x1F, 0x4B, 0xBD, 0x8B, 0x8A],
        [0x70, 0x3E, 0xB5, 0x66, 0x48, 0x03, 0xF6, 0x0E, 0x61, 0x35, 0x57, 0xB9, 0x86, 0xC1, 0x1D, 0x9E],
        [0xE1, 0xF8, 0x98, 0x11, 0x69, 0xD9, 0x8E, 0x94, 0x9B, 0x1E, 0x87, 0xE9, 0xCE, 0x55, 0x28, 0xDF],
        [0x8C, 0xA1, 0x89, 0x0D, 0xBF, 0xE6, 0x42, 0x68, 0x41, 0x99, 0x2D, 0x0F, 0xB0, 0x54, 0xBB, 0x16],
        ]
    def set_block(self,block):
        self.block=block
    
    def set_key(self,key):
        self.key=key
    
    def add_round_key(self):
        if len(self.block) != len(self.key):
            raise ValueError("Block and key lengths don't match")
        encrypted_matrix = []
        for i in range(len(self.block)):
            encrypted_row = []
            for j in range(len(self.block[i])):
                block_byte = int(self.block[i][j], 16)
                key_byte = int(self.key[i][j], 16)
                result_byte = block_byte ^ key_byte
                encrypted_row.append('{:02X}'.format(result_byte))
            encrypted_matrix.append(encrypted_row)
        self.encrypted_matrix = encrypted_matrix
        self.block = self.encrypted_matrix
        return encrypted_matrix

    
    
    def byte_subs(self):
        # self.block=[['EA','04','65','85'],['83','45','5D','96'],['5C','33','98','B0'],['F0','2D','AD','C5']]
        self.encrypted_matrix = self.block
        for i in range(len(self.encrypted_matrix)):
            for k in range(len(self.encrypted_matrix[i])):
                row = self.encrypted_matrix[i][k][0]
                col = self.encrypted_matrix[i][k][1]
                row = int(row, 16)
                col = int(col, 16)
                # print(row," ",col)
                substituted_value = self.s_box[row][col] 
                self.encrypted_matrix[i][k] = hex(substituted_value)
        self.block=self.encrypted_matrix
        return(self.encrypted_matrix)
    
    def shift_rows(self):
        # self.block = [
        #     ['87', 'F2', '4D', '97'],
        #     ['EC', '6E', '4C', '90'],
        #     ['4A', 'C3', '46', 'E7'],
        #     ['8C', 'D8', '95', 'A6']
        # ] 
        self.encrypted_matrix=self.block
        for i in range(1, len(self.encrypted_matrix)):
            value=[]
            for j in range (i):
                value.append(self.encrypted_matrix[i][j])
            # print(value)
            array=[]
            for k in range (j+1,len(self.encrypted_matrix[i])):
                # print(self.encrypted_matrix[i][k])
                array.append(self.encrypted_matrix[i][k])
            array+=(value)
            # print(array)
            self.encrypted_matrix[i]=array
        self.block=self.encrypted_matrix
        return self.encrypted_matrix
    
    def multiply(self, a, b):
        result = 0
        while b:
            if b & 1:
                result ^= a
            a <<= 1
            if a & 0x100:
                a ^= 0x11b  # Reduction polynomial
            b >>= 1
        return result
    
    
    
    def mix_columns(self):
        state = self.block
        mixed_state = []
        for i in range(4):
            column = [int(state[j][i], 16) for j in range(4)]
            mixed_column = []
            for _ in range(4):
                mixed_value = (
                    self.multiply(0x02, column[0])
                    ^ self.multiply(0x03, column[1])
                    ^ column[2]
                    ^ column[3]
                )
                mixed_column.append(mixed_value)
                column = column[1:] + [column[0]]
            mixed_state.append(mixed_column)
        transposed_mixed_state = [list(row) for row in zip(*mixed_state)]
        hex_transposed_mixed_state = [
            ['{:02X}'.format(value) for value in row] for row in transposed_mixed_state
        ]
        self.block = hex_transposed_mixed_state
        return hex_transposed_mixed_state

    
    def encrypt(self, rounds=10):
        for round_count in range(rounds):
            round_key = globals()[f'key{round_count}']
            self.set_key(round_key)

            print(f"Round {round_count + 1} Key:")
            for row in self.key:
                print(row)
            print("\nRound Initial State Matrix:")
            for row in self.block:
                print(row)
            print("---------------------")

            self.add_round_key()

            print(f"Round {round_count + 1} After AddRoundKey:")
            for row in self.block:
                print(row)
            print("---------------------")

            self.byte_subs()

            print(f"Round {round_count + 1} After ByteSubs:")
            for row in self.block:
                print(row)
            print("---------------------")

            self.shift_rows()

            print(f"Round {round_count + 1} After ShiftRows:")
            for row in self.block:
                print(row)
            print("---------------------")

            if round_count < rounds - 1:  # Don't mix columns in the last round
                self.mix_columns()

                print(f"Round {round_count + 1} After MixColumns:")
                for row in self.block:
                    print(row)
                print("=====================")

        return self.encrypted_matrix

    








aes=AES()

# add_round_key_value=aes.add_round_key()
# # print('add_round_key_vallue ',add_round_key_value)
# bytes_subs_value=aes.byte_subs()
# # print('bytes_subs_value ', bytes_subs_value)
# shift_row_value=aes.shift_rows()
# # print('shift_row_value ',shift_row_value)
# mix_columns_value=aes.mix_columns()
# # print('mix_columns_value ',mix_columns_value)
encrypted_result = aes.encrypt(rounds=10)
print(encrypted_result)
# Out:
# Round 1 Key:
# ['AC', '19', '28', '57']
# ['77', 'FA', 'D1', '5C']
# ['66', 'DC', '29', '00']
# ['F3', '21', '41', '6A']
#
# Round Initial State Matrix:
# ['47', '40', 'A3', '4C']
# ['37', 'D4', '70', '9F']
# ['94', 'E4', '3A', '42']
# ['ED', 'A5', 'A6', 'BC']
# ---------------------
# Round 1 After AddRoundKey:
# ['EB', '59', '8B', '1B']
# ['40', '2E', 'A1', 'C3']
# ['F2', '38', '13', '42']
# ['1E', '84', 'E7', 'D6']
# ---------------------
# Round 1 After ByteSubs:
# ['0xe9', '0xcb', '0x3d', '0xaf']
# ['0x9', '0x31', '0x32', '0x2e']
# ['0x89', '0x7', '0x7d', '0x2c']
# ['0x72', '0x5f', '0x94', '0xf6']
# ---------------------
# Round 1 After ShiftRows:
# ['0xe9', '0xcb', '0x3d', '0xaf']
# ['0x31', '0x32', '0x2e', '0x9']
# ['0x7d', '0x2c', '0x89', '0x7']
# ['0xf6', '0x72', '0x5f', '0x94']
# ---------------------
# Round 1 After MixColumns:
# ['11', '85', 'DE', 'CD']
# ['FA', 'A9', 'BE', '20']
# ['23', '37', 'FB', '0F']
# ['9B', 'BC', '5E', 'D7']
# =====================
# Round 2 Key:
# ['51', '9A', '2A', '5B']
# ['26', '60', 'FB', '07']
# ['40', 'BC', 'D2', '07']
# ['B3', '9D', '93', '6D']
#
# Round Initial State Matrix:
# ['11', '85', 'DE', 'CD']
# ['FA', 'A9', 'BE', '20']
# ['23', '37', 'FB', '0F']
# ['9B', 'BC', '5E', 'D7']
# ---------------------
# Round 2 After AddRoundKey:
# ['40', '1F', 'F4', '96']
# ['DC', 'C9', '45', '27']
# ['63', '8B', '29', '08']
# ['28', '21', 'CD', 'BA']
# ---------------------
# Round 2 After ByteSubs:
# ['0x9', '0xc0', '0xbf', '0x90']
# ['0x86', '0xdd', '0x6e', '0xcc']
# ['0xfb', '0x3d', '0xa5', '0x30']
# ['0x34', '0xfd', '0xbd', '0xf4']
# ---------------------
# Round 2 After ShiftRows:
# ['0x9', '0xc0', '0xbf', '0x90']
# ['0xdd', '0x6e', '0xcc', '0x86']
# ['0xa5', '0x30', '0xfb', '0x3d']
# ['0xf4', '0x34', '0xfd', '0xbd']
# ---------------------
# Round 2 After MixColumns:
# ['3F', '2D', '2C', '2A']
# ['A8', '78', 'D7', '7D']
# ['82', '92', '82', 'B0']
# ['90', '6D', '0C', '71']
# =====================
# Round 3 Key:
# ['0F', '46', '16', '34']
# ['29', '26', 'ED', '33']
# ['69', '9A', '3F', '34']
# ['DA', '07', 'AC', '59']
#
# Round Initial State Matrix:
# ['3F', '2D', '2C', '2A']
# ['A8', '78', 'D7', '7D']
# ['82', '92', '82', 'B0']
# ['90', '6D', '0C', '71']
# ---------------------
# Round 3 After AddRoundKey:
# ['30', '6B', '3A', '1E']
# ['81', '5E', '3A', '4E']
# ['EB', '08', 'BD', '84']
# ['4A', '6A', 'A0', '28']
# ---------------------
# Round 3 After ByteSubs:
# ['0x4', '0x7f', '0x80', '0x72']
# ['0xc', '0x58', '0x80', '0x2f']
# ['0xe9', '0x30', '0x7a', '0x5f']
# ['0xd6', '0x2', '0xe0', '0x34']
# ---------------------
# Round 3 After ShiftRows:
# ['0x4', '0x7f', '0x80', '0x72']
# ['0x58', '0x80', '0x2f', '0xc']
# ['0x7a', '0x5f', '0xe9', '0x30']
# ['0x34', '0xd6', '0x2', '0xe0']
# ---------------------
# Round 3 After MixColumns:
# ['AE', 'EC', '81', '20']
# ['0E', '53', 'FC', 'DA']
# ['F4', '20', '60', '25']
# ['46', 'E9', '59', '71']
# =====================
# Round 4 Key:
# ['CA', 'D7', 'DD', '67']
# ['E3', 'F1', '30', '54']
# ['8A', '6B', '0F', '60']
# ['50', '6C', 'A3', '39']
#
# Round Initial State Matrix:
# ['AE', 'EC', '81', '20']
# ['0E', '53', 'FC', 'DA']
# ['F4', '20', '60', '25']
# ['46', 'E9', '59', '71']
# ---------------------
# Round 4 After AddRoundKey:
# ['64', '3B', '5C', '47']
# ['ED', 'A2', 'CC', '8E']
# ['7E', '4B', '6F', '45']
# ['16', '85', 'FA', '48']
# ---------------------
# Round 4 After ByteSubs:
# ['0x43', '0xe2', '0x4a', '0xa0']
# ['0x55', '0x3a', '0x4b', '0x19']
# ['0xf3', '0xb3', '0xa8', '0x6e']
# ['0x47', '0x97', '0x2d', '0x52']
# ---------------------
# Round 4 After ShiftRows:
# ['0x43', '0xe2', '0x4a', '0xa0']
# ['0x3a', '0x4b', '0x19', '0x55']
# ['0xa8', '0x6e', '0xf3', '0xb3']
# ['0x52', '0x47', '0x97', '0x2d']
# ---------------------
# Round 4 After MixColumns:
# ['32', '2B', 'DB', '3A']
# ['86', '81', 'E1', 'E9']
# ['C4', 'BC', '0C', 'FF']
# ['F3', '96', '01', '47']
# =====================
# Round 5 Key:
# ['9A', 'DD', 'CF', '3C']
# ['79', '2C', 'FF', '68']
# ['F3', '47', 'F0', '08']
# ['A3', '2B', '53', '31']
#
# Round Initial State Matrix:
# ['32', '2B', 'DB', '3A']
# ['86', '81', 'E1', 'E9']
# ['C4', 'BC', '0C', 'FF']
# ['F3', '96', '01', '47']
# ---------------------
# Round 5 After AddRoundKey:
# ['A8', 'F6', '14', '06']
# ['FF', 'AD', '1E', '81']
# ['37', 'FB', 'FC', 'F7']
# ['50', 'BD', '52', '76']
# ---------------------
# Round 5 After ByteSubs:
# ['0xc2', '0x42', '0xfa', '0x6f']
# ['0x16', '0x95', '0x72', '0xc']
# ['0x9a', '0xf', '0xb0', '0x68']
# ['0x53', '0x7a', '0x0', '0x38']
# ---------------------
# Round 5 After ShiftRows:
# ['0xc2', '0x42', '0xfa', '0x6f']
# ['0x95', '0x72', '0xc', '0x16']
# ['0xb0', '0x68', '0x9a', '0xf']
# ['0x38', '0x53', '0x7a', '0x0']
# ---------------------
# Round 5 After MixColumns:
# ['B3', '29', '1B', 'EB']
# ['00', '4D', '2D', '52']
# ['64', '15', '57', '67']
# ['08', '7A', '77', 'A8']
# =====================
# Round 6 Key:
# ['6B', '30', '08', '26']
# ['12', '1C', 'F7', '4E']
# ['E1', '5B', '07', '46']
# ['42', '70', '54', '77']
#
# Round Initial State Matrix:
# ['B3', '29', '1B', 'EB']
# ['00', '4D', '2D', '52']
# ['64', '15', '57', '67']
# ['08', '7A', '77', 'A8']
# ---------------------
# Round 6 After AddRoundKey:
# ['D8', '19', '13', 'CD']
# ['12', '51', 'DA', '1C']
# ['85', '4E', '50', '21']
# ['4A', '0A', '23', 'DF']
# ---------------------
# Round 6 After ByteSubs:
# ['0x61', '0xd4', '0x7d', '0xbd']
# ['0xc9', '0xd1', '0x57', '0x9c']
# ['0x97', '0x2f', '0x53', '0xfd']
# ['0xd6', '0x67', '0x26', '0x9e']
# ---------------------
# Round 6 After ShiftRows:
# ['0x61', '0xd4', '0x7d', '0xbd']
# ['0xd1', '0x57', '0x9c', '0xc9']
# ['0x53', '0xfd', '0x97', '0x2f']
# ['0x9e', '0xd6', '0x67', '0x26']
# ---------------------
# Round 6 After MixColumns:
# ['67', '61', 'B5', '28']
# ['B3', 'B0', '9B', '63']
# ['AF', '03', '7D', '40']
# ['06', '7A', '42', '76']
# =====================
# Round 7 Key:
# ['3A', '10', 'FD', '2A']
# ['28', '0C', '0A', '64']
# ['C9', '57', '0D', '22']
# ['8B', '27', '59', '55']
#
# Round Initial State Matrix:
# ['67', '61', 'B5', '28']
# ['B3', 'B0', '9B', '63']
# ['AF', '03', '7D', '40']
# ['06', '7A', '42', '76']
# ---------------------
# Round 7 After AddRoundKey:
# ['5D', '71', '48', '02']
# ['9B', 'BC', '91', '07']
# ['66', '54', '70', '62']
# ['8D', '5D', '1B', '23']
# ---------------------
# Round 7 After ByteSubs:
# ['0x4c', '0xa3', '0x52', '0x77']
# ['0x14', '0x65', '0x81', '0xc5']
# ['0x33', '0x20', '0x51', '0xaa']
# ['0x5d', '0x4c', '0xaf', '0x26']
# ---------------------
# Round 7 After ShiftRows:
# ['0x4c', '0xa3', '0x52', '0x77']
# ['0x65', '0x81', '0xc5', '0x14']
# ['0x51', '0xaa', '0x33', '0x20']
# ['0x26', '0x5d', '0x4c', '0xaf']
# ---------------------
# Round 7 After MixColumns:
# ['40', '32', '8F', '5D']
# ['53', '02', 'DA', '90']
# ['E1', '8A', '25', 'C9']
# ['AC', '6F', '98', 'E8']
# =====================
# Round 8 Key:
# ['F6', 'DB', '01', '57']
# ['DE', 'D7', '0B', '33']
# ['17', '80', '06', '11']
# ['9C', 'A7', '5F', '44']
#
# Round Initial State Matrix:
# ['40', '32', '8F', '5D']
# ['53', '02', 'DA', '90']
# ['E1', '8A', '25', 'C9']
# ['AC', '6F', '98', 'E8']
# ---------------------
# Round 8 After AddRoundKey:
# ['B6', 'E9', '8E', '0A']
# ['8D', 'D5', 'D1', 'A3']
# ['F6', '0A', '23', 'D8']
# ['30', 'C8', 'C7', 'AC']
# ---------------------
# Round 8 After ByteSubs:
# ['0x4e', '0x1e', '0x19', '0x67']
# ['0x5d', '0x3', '0x3e', '0xa']
# ['0x42', '0x67', '0x26', '0x61']
# ['0x4', '0xe8', '0xc6', '0x91']
# ---------------------
# Round 8 After ShiftRows:
# ['0x4e', '0x1e', '0x19', '0x67']
# ['0x3', '0x3e', '0xa', '0x5d']
# ['0x26', '0x61', '0x42', '0x67']
# ['0x91', '0x4', '0xe8', '0xc6']
# ---------------------
# Round 8 After MixColumns:
# ['2E', '1B', '86', '88']
# ['B3', 'C5', '23', 'B2']
# ['A9', 'EE', 'B4', 'A5']
# ['CE', '75', 'A8', '04']
# =====================
# Round 9 Key:
# ['AA', '14', '1A', '09']
# ['74', 'C3', '11', '3A']
# ['63', '43', '17', '2B']
# ['FF', 'E4', '48', '6F']
#
# Round Initial State Matrix:
# ['2E', '1B', '86', '88']
# ['B3', 'C5', '23', 'B2']
# ['A9', 'EE', 'B4', 'A5']
# ['CE', '75', 'A8', '04']
# ---------------------
# Round 9 After AddRoundKey:
# ['84', '0F', '9C', '81']
# ['C7', '06', '32', '88']
# ['CA', 'AD', 'A3', '8E']
# ['31', '91', 'E0', '6B']
# ---------------------
# Round 9 After ByteSubs:
# ['0x5f', '0x76', '0xde', '0xc']
# ['0xc6', '0x6f', '0x23', '0xc4']
# ['0x74', '0x95', '0xa', '0x19']
# ['0xc7', '0x81', '0xe1', '0x7f']
# ---------------------
# Round 9 After ShiftRows:
# ['0x5f', '0x76', '0xde', '0xc']
# ['0x6f', '0x23', '0xc4', '0xc6']
# ['0xa', '0x19', '0x74', '0x95']
# ['0x7f', '0xc7', '0x81', '0xe1']
# ---------------------
# Round 9 After MixColumns:
# ['7A', '57', '05', '3D']
# ['E0', 'DC', '50', 'DE']
# ['A5', '35', '6A', 'C3']
# ['7A', '35', 'D0', '9E']
# =====================
# Round 10 Key:
# ['C3', '46', 'B2', '04']
# ['B7', '85', 'A3', '3E']
# ['D4', 'C6', 'B4', '15']
# ['2B', '22', 'FC', '7A']
#
# Round Initial State Matrix:
# ['7A', '57', '05', '3D']
# ['E0', 'DC', '50', 'DE']
# ['A5', '35', '6A', 'C3']
# ['7A', '35', 'D0', '9E']
# ---------------------
# Round 10 After AddRoundKey:
# ['B9', '11', 'B7', '39']
# ['57', '59', 'F3', 'E0']
# ['71', 'F3', 'DE', 'D6']
# ['51', '17', '2C', 'E4']
# ---------------------
# Round 10 After ByteSubs:
# ['0x56', '0x82', '0xa9', '0x12']
# ['0x5b', '0xcb', '0xd', '0xe1']
# ['0xa3', '0xd', '0x1d', '0xf6']
# ['0xd1', '0xf0', '0x71', '0x69']
# ---------------------
# Round 10 After ShiftRows:
# ['0x56', '0x82', '0xa9', '0x12']
# ['0xcb', '0xd', '0xe1', '0x5b']
# ['0x1d', '0xf6', '0xa3', '0xd']
# ['0x69', '0xd1', '0xf0', '0x71']
# ---------------------
# [['0x56', '0x82', '0xa9', '0x12'], ['0xcb', '0xd', '0xe1', '0x5b'], ['0x1d', '0xf6', '0xa3', '0xd'], ['0x69', '0xd1', '0xf0', '0x71']]

# %% [markdown]
# ## key expansion again

# %%
key = [
    ["54", "68", "61", "74"],
    ["73", "20", "6d", "79"],
    ["20", "4b", "75", "6e"],
    ["67", "20", "46", "75"],
]

s_box = [
        [0x63, 0x7C, 0x77, 0x7B, 0xF2, 0x6B, 0x6F, 0xC5, 0x30, 0x01, 0x67, 0x2B, 0xFE, 0xD7, 0xAB, 0x76],
        [0xCA, 0x82, 0xC9, 0x7D, 0xFA, 0x59, 0x47, 0xF0, 0xAD, 0xD4, 0xA2, 0xAF, 0x9C, 0xA4, 0x72, 0xC0],
        [0xB7, 0xFD, 0x93, 0x26, 0x36, 0x3F, 0xF7, 0xCC, 0x34, 0xA5, 0xE5, 0xF1, 0x71, 0xD8, 0x31, 0x15],
        [0x04, 0xC7, 0x23, 0xC3, 0x18, 0x96, 0x05, 0x9A, 0x07, 0x12, 0x80, 0xE2, 0xEB, 0x27, 0xB2, 0x75],
        [0x09, 0x83, 0x2C, 0x1A, 0x1B, 0x6E, 0x5A, 0xA0, 0x52, 0x3B, 0xD6, 0xB3, 0x29, 0xE3, 0x2F, 0x84],
        [0x53, 0xD1, 0x00, 0xED, 0x20, 0xFC, 0xB1, 0x5B, 0x6A, 0xCB, 0xBE, 0x39, 0x4A, 0x4C, 0x58, 0xCF],
        [0xD0, 0xEF, 0xAA, 0xFB, 0x43, 0x4D, 0x33, 0x85, 0x45, 0xF9, 0x02, 0x7F, 0x50, 0x3C, 0x9F, 0xA8],
        [0x51, 0xA3, 0x40, 0x8F, 0x92, 0x9D, 0x38, 0xF5, 0xBC, 0xB6, 0xDA, 0x21, 0x10, 0xFF, 0xF3, 0xD2],
        [0xCD, 0x0C, 0x13, 0xEC, 0x5F, 0x97, 0x44, 0x17, 0xC4, 0xA7, 0x7E, 0x3D, 0x64, 0x5D, 0x19, 0x73],
        [0x60, 0x81, 0x4F, 0xDC, 0x22, 0x2A, 0x90, 0x88, 0x46, 0xEE, 0xB8, 0x14, 0xDE, 0x5E, 0x0B, 0xDB],
        [0xE0, 0x32, 0x3A, 0x0A, 0x49, 0x06, 0x24, 0x5C, 0xC2, 0xD3, 0xAC, 0x62, 0x91, 0x95, 0xE4, 0x79],
        [0xE7, 0xC8, 0x37, 0x6D, 0x8D, 0xD5, 0x4E, 0xA9, 0x6C, 0x56, 0xF4, 0xEA, 0x65, 0x7A, 0xAE, 0x08],
        [0xBA, 0x78, 0x25, 0x2E, 0x1C, 0xA6, 0xB4, 0xC6, 0xE8, 0xDD, 0x74, 0x1F, 0x4B, 0xBD, 0x8B, 0x8A],
        [0x70, 0x3E, 0xB5, 0x66, 0x48, 0x03, 0xF6, 0x0E, 0x61, 0x35, 0x57, 0xB9, 0x86, 0xC1, 0x1D, 0x9E],
        [0xE1, 0xF8, 0x98, 0x11, 0x69, 0xD9, 0x8E, 0x94, 0x9B, 0x1E, 0x87, 0xE9, 0xCE, 0x55, 0x28, 0xDF],
        [0x8C, 0xA1, 0x89, 0x0D, 0xBF, 0xE6, 0x42, 0x68, 0x41, 0x99, 0x2D, 0x0F, 0xB0, 0x54, 0xBB, 0x16],
        ]

r_con = [ '0x01', '0x02', '0x04', '0x08', '0x10', '0x20', '0x40','0x80', '0x1B', '0x36']







# print(words[len(words)-1])



def root_word(word):
    shifted_word = word[1:] + [word[0]]
    return shifted_word

def sub_word(word):
    for i in range(len(word)):
        row = int(word[i][0], 16)
        col = int(word[i][1], 16)
        substituted_value = s_box[row][col]
        word[i] = hex(substituted_value)[2:].zfill(2)
    return word

def g_function(word, index):
    word = root_word(word)
    word = sub_word(word)
    word = round_constant_step(word, index)
    return word

def round_constant_step(word, index):
    Round_contant = [int(r_con[index], 16), 0, 0, 0]
    word = [int(x, 16) for x in word]
    result = [Round_contant[i] ^ word[i] for i in range(len(Round_contant))]
    result = [hex(val)[2:].zfill(2) for val in result]
    return result


def xor_maker(first_operand,second_operand):
    result = [int(first_operand[i],16) ^ int(second_operand[i],16) for i in range(len(first_operand))]
    result = [hex(val)[2:].zfill(2) for val in result]
    return result




def words_maker(words):
    round_index=0
    g_output=g_function(words[-1],round_index)
    new_words=[]
    for i in range (0,4):
        g_output=xor_maker(g_output,words[i])
        new_words.append(g_output)
    return new_words




def key_expansion(key):
    transposed_key = [list(row) for row in zip(*key)]
    columns = list(map(list, zip(*transposed_key)))
    words = []
    for col in columns:
        words.append(col)
    print('words in orgin ',words)
    key_array = []
    key_array.append(words)
    # print("before g function ",words[len(words) - 1])
    # print("after g_function ",g_function(words[len(words) - 1],8))
    i=0
    while i<10:
        key_array.append(words_maker(key_array[-1]))
        i+=1


    return key_array










new_key = key_expansion(key)
for round_key in new_key:
    print(round_key)


key = [
    ["54", "68", "61", "74"],
    ["73", "20", "6d", "79"],
    ["20", "4b", "75", "6e"],
    ["67", "20", "46", "75"],
]
#    Round 0: 54 68 61 74 73 20 6D 79 20 4B 75 6E 67 20 46 75
#  • Round 1: E2 32 FC F1 91 12 91 88 B1 59 E4 E6 D6 79 A2 93
#  • Round 2: 56 08 20 07 C7 1A B1 8F 76 43 55 69 A0 3A F7 FA
#  • Round 3: D2 60 0D E7 15 7A BC 68 63 39 E9 01 C3 03 1E FB
#  • Round 4: A1 12 02 C9 B4 68 BE A1 D7 51 57 A0 14 52 49 5B
#  • Round 5: B1 29 3B 33 05 41 85 92 D2 10 D2 32 C6 42 9B 69
#  • Round 6: BD 3D C2 B7 B8 7C 47 15 6A 6C 95 27 AC 2E 0E 4E
#  • Round 7: CC 96 ED 16 74 EA AA 03 1E 86 3F 24 B2 A8 31 6A
#  • Round 8: 8E 51 EF 21 FA BB 45 22 E4 3D 7A 06 56 95 4B 6C
#  • Round 9: BF E2 BF 90 45 59 FA B2 A1 64 80 B4 F7 F1 CB D8
#  • Round 10: 28 FD DE F8 6D A4 24 4A CC C0 A4 FE 3B 31 6F 26
# Out:
# words in orgin  [['54', '68', '61', '74'], ['73', '20', '6d', '79'], ['20', '4b', '75', '6e'], ['67', '20', '46', '75']]
# [['54', '68', '61', '74'], ['73', '20', '6d', '79'], ['20', '4b', '75', '6e'], ['67', '20', '46', '75']]
# [['e2', '32', 'fc', 'f1'], ['91', '12', '91', '88'], ['b1', '59', 'e4', 'e6'], ['d6', '79', 'a2', '93']]
# [['55', '08', '20', '07'], ['c4', '1a', 'b1', '8f'], ['75', '43', '55', '69'], ['a3', '3a', 'f7', 'fa']]
# [['d4', '60', '0d', '0d'], ['10', '7a', 'bc', '82'], ['65', '39', 'e9', 'eb'], ['c6', '03', '1e', '11']]
# [['ae', '12', '8f', 'b9'], ['be', '68', '33', '3b'], ['db', '51', 'da', 'd0'], ['1d', '52', 'c4', 'c1']]
# [['af', '0e', 'f7', '1d'], ['11', '66', 'c4', '26'], ['ca', '37', '1e', 'f6'], ['d7', '65', 'da', '37']]
# [['e3', '59', '6d', '13'], ['f2', '3f', 'a9', '35'], ['38', '08', 'b7', 'c3'], ['ef', '6d', '6d', 'f4']]
# [['de', '65', 'd2', 'cc'], ['2c', '5a', '7b', 'f9'], ['14', '52', 'cc', '3a'], ['fb', '3f', 'a1', 'ce']]
# [['aa', '57', '59', 'c3'], ['86', '0d', '22', '3a'], ['92', '5f', 'ee', '00'], ['69', '60', '4f', 'ce']]
# [['7b', 'd3', 'd2', '3a'], ['fd', 'de', 'f0', '00'], ['6f', '81', '1e', '00'], ['06', 'e1', '51', 'ce']]
# [['82', '02', '59', '55'], ['7f', 'dc', 'a9', '55'], ['10', '5d', 'b7', '55'], ['16', 'bc', 'e6', '9b']]

# %%
class aes_decryption:
    def __init__(self):
        self.block=[]
        self.key=[]
        self.r_con = (
                        0x00, 0x01, 0x02, 0x04, 0x08, 0x10, 0x20, 0x40,
                        0x80, 0x1B, 0x36, 0x6C, 0xD8, 0xAB, 0x4D, 0x9A,
                        0x2F, 0x5E, 0xBC, 0x63, 0xC6, 0x97, 0x35, 0x6A,
                        0xD4, 0xB3, 0x7D, 0xFA, 0xEF, 0xC5, 0x91, 0x39,
                    )
        self.encrypted_matrix=[]
        self.inv_s_box = [
            ['52', '09', '6A', 'D5', '30', '36', 'A5', '38', 'BF', '40', 'A3', '9E', '81', 'F3', 'D7', 'FB'],
            ['7C', 'E3', '39', '82', '9B', '2F', 'FF', '87', '34', '8E', '43', '44', 'C4', 'DE', 'E9', 'CB'],
            ['54', '7B', '94', '32', 'A6', 'C2', '23', '3D', 'EE', '4C', '95', '0B', '42', 'FA', 'C3', '4E'],
            ['08', '2E', 'A1', '66', '28', 'D9', '24', 'B2', '76', '5B', 'A2', '49', '6D', '8B', 'D1', '25'],
            ['72', 'F8', 'F6', '64', '86', '68', '98', '16', 'D4', 'A4', '5C', 'CC', '5D', '65', 'B6', '92'],
            ['6C', '70', '48', '50', 'FD', 'ED', 'B9', 'DA', '5E', '15', '46', '57', 'A7', '8D', '9D', '84'],
            ['90', 'D8', 'AB', '00', '8C', 'BC', 'D3', '0A', 'F7', 'E4', '58', '05', 'B8', 'B3', '45', '06'],
            ['D0', '2C', '1E', '8F', 'CA', '3F', '0F', '02', 'C1', 'AF', 'BD', '03', '01', '13', '8A', '6B'],
            ['3A', '91', '11', '41', '4F', '67', 'DC', 'EA', '97', 'F2', 'CF', 'CE', 'F0', 'B4', 'E6', '73'],
            ['96', 'AC', '74', '22', 'E7', 'AD', '35', '85', 'E2', 'F9', '37', 'E8', '1C', '75', 'DF', '6E'],
            ['47', 'F1', '1A', '71', '1D', '29', 'C5', '89', '6F', 'B7', '62', '0E', 'AA', '18', 'BE', '1B'],
            ['FC', '56', '3E', '4B', 'C6', 'D2', '79', '20', '9A', 'DB', 'C0', 'FE', '78', 'CD', '5A', 'F4'],
            ['1F', 'DD', 'A8', '33', '88', '07', 'C7', '31', 'B1', '12', '10', '59', '27', '80', 'EC', '5F'],
            ['60', '51', '7F', 'A9', '19', 'B5', '4A', '0D', '2D', 'E5', '7A', '9F', '93', 'C9', '9C', 'EF'],
            ['A0', 'E0', '3B', '4D', 'AE', '2A', 'F5', 'B0', 'C8', 'EB', 'BB', '3C', '83', '53', '99', '61'],
            ['17', '2B', '04', '7E', 'BA', '77', 'D6', '26', 'E1', '69', '14', '63', '55', '21', '0C', '7D']
        ]
        
    def set_block(self,block):
        self.block=block
    
    def set_key(self,key):
        self.key=key
    
    def add_round_key(self):
        if len(self.block) != len(self.key):
            raise ValueError("Block and key lengths don't match")
        encrypted_matrix = []
        for i in range(len(self.block)):
            encrypted_row = []
            for j in range(len(self.block[i])):
                block_byte = int(self.block[i][j], 16)
                key_byte = int(self.key[i][j], 16)
                result_byte = block_byte ^ key_byte
                encrypted_row.append('{:02X}'.format(result_byte))
            encrypted_matrix.append(encrypted_row)
        self.encrypted_matrix = encrypted_matrix
        self.block = self.encrypted_matrix
        return encrypted_matrix

    
    
    def inv_byte_subs(self):
        # Use the inverse S-box for byte substitution
        self.encrypted_matrix = self.block
        for i in range(len(self.encrypted_matrix)):
            for k in range(len(self.encrypted_matrix[i])):
                row = self.encrypted_matrix[i][k][0]
                col = self.encrypted_matrix[i][k][1]
                row = int(row, 16)
                col = int(col, 16)
                substituted_value = self.inv_s_box[row][col]  # Use inverse S-box
                self.encrypted_matrix[i][k] = hex(substituted_value)
        self.block = self.encrypted_matrix
        return self.encrypted_matrix
    
    def inv_shift_rows(self):
        # Similar to shift_rows but in the inverse direction
        self.encrypted_matrix = self.block
        for i in range(1, len(self.encrypted_matrix)):
            value = []
            for j in range(len(self.encrypted_matrix[i]))[::-1]:
                value.append(self.encrypted_matrix[i][j])
            array = value[-i:] + value[:-i]
            self.encrypted_matrix[i] = array
        self.block = self.encrypted_matrix
        return self.encrypted_matrix
    
    def multiply(self, a, b):
        result = 0
        while b:
            if b & 1:
                result ^= a
            a <<= 1
            if a & 0x100:
                a ^= 0x11b  # Reduction polynomial
            b >>= 1
        return result
    
    
    
    def inv_mix_columns(self):
        state = self.block
        inv_mixed_state = []
        for i in range(4):
            column = [int(state[j][i], 16) for j in range(4)]
            inv_mixed_column = []
            for _ in range(4):
                inv_mixed_value = (
                    self.multiply(0x0e, column[0])
                    ^ self.multiply(0x0b, column[1])
                    ^ self.multiply(0x0d, column[2])
                    ^ self.multiply(0x09, column[3])
                )
                inv_mixed_column.append(inv_mixed_value)
                column = column[1:] + [column[0]]
            inv_mixed_state.append(inv_mixed_column)
        transposed_inv_mixed_state = [list(row) for row in zip(*inv_mixed_state)]
        hex_transposed_inv_mixed_state = [
            ['{:02X}'.format(value) for value in row] for row in transposed_inv_mixed_state
        ]
        self.block = hex_transposed_inv_mixed_state
        return hex_transposed_inv_mixed_state
    
    
    def decrypt(self, rounds=10):
        # Reversing the order of operations
        key_schedule = []
        state_rounds = []

        # AddRoundKey for Round 10
        self.set_key(globals()[f'key{rounds - 1}'])
        self.add_round_key()
        state_rounds.append(self.block)

        # Inverse ShiftRows and Inverse ByteSubs for Rounds 9 to 1
        for i in range(rounds - 1, 0, -1):
            self.inv_shift_rows()
            self.inv_byte_subs()
            self.set_key(globals()[f'key{i - 1}'])
            self.add_round_key()
            key_schedule.insert(0, self.key)
            state_rounds.insert(0, self.block)
            self.inv_mix_columns()

        # Final Inverse ShiftRows and Inverse ByteSubs for Round 0
        self.inv_shift_rows()
        self.inv_byte_subs()
        self.set_key(globals()['key0'])
        self.add_round_key()
        state_rounds.insert(0, self.block)

        return key_schedule, state_rounds
